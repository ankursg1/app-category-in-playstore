# %%
import numpy as np
from sklearn.impute import SimpleImputer
import pandas as pd

# %%
df.iloc[ : , 2:3 ].values
# Out:
# array([[4.1       ],
#        [3.9       ],
#        [4.7       ],
#        ...,
#        [4.19333832],
#        [4.5       ],
#        [4.5       ]])

# %%
df = pd.read_csv('googleplaystore.csv')

impute = SimpleImputer(missing_values = np.nan , strategy = 'mean')
impute.fit(df.iloc[ : , 2:3 ].values)
df.iloc[ : , 2:3 ] = impute.transform(df.iloc[ : , 2:3 ].values)

df = df.dropna()

df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df['Category']
# Out:
# 0             ART_AND_DESIGN
# 1             ART_AND_DESIGN
# 2             ART_AND_DESIGN
# 3             ART_AND_DESIGN
# 4             ART_AND_DESIGN
#                 ...
# 10836                 FAMILY
# 10837                 FAMILY
# 10838                MEDICAL
# 10839    BOOKS_AND_REFERENCE
# 10840              LIFESTYLE
# Name: Category, Length: 10829, dtype: object

# %%
df['Category']=='BOOKS_AND_REFERENCE'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10836    False
# 10837    False
# 10838    False
# 10839     True
# 10840    False
# Name: Category, Length: 10829, dtype: bool

# %%
df[df['Category']=='BOOKS_AND_REFERENCE']
# Out:
#                                       App             Category  Rating  \
# 139                  Wattpad 📖 Free Books  BOOKS_AND_REFERENCE     4.6
# 140      E-Book Read - Read Book for free  BOOKS_AND_REFERENCE     4.5
# 141    Download free book with green book  BOOKS_AND_REFERENCE     4.6
# 142                             Wikipedia  BOOKS_AND_REFERENCE     4.4
# 143                         Amazon Kindle  BOOKS_AND_REFERENCE     4.2
# ...                                   ...                  ...     ...
# 10815           Golden Dictionary (FR-AR)  BOOKS_AND_REFERENCE     4.2
# 10819                           Fanfic-FR  BOOKS_AND_REFERENCE     3.3
# 10829      Bulgarian French Dictionary Fr  BOOKS_AND_REFERENCE     4.6
# 10833                         Chemin (fr)  BOOKS_AND_REFERENCE     4.8
# 10839       The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE     4.5
#
#        Reviews                Size      Installs  Type Price Content Rating  \
# ...

# %%
len(df[df['Category']=='BOOKS_AND_REFERENCE'])
# Out:
# 230

# %%
df_pr=df[df['Category']=='BOOKS_AND_REFERENCE']

# %% [markdown]
# ## free apps of category BOOKS_AND_REFERENCE

# %%
df_pr['Type']=='Free'
# Out:
# 139      True
# 140      True
# 141      True
# 142      True
# 143      True
#          ...
# 10815    True
# 10819    True
# 10829    True
# 10833    True
# 10839    True
# Name: Type, Length: 230, dtype: bool

# %%
df_pr[df_pr['Type']=='Free']
# Out:
#                                       App             Category  Rating  \
# 139                  Wattpad 📖 Free Books  BOOKS_AND_REFERENCE     4.6
# 140      E-Book Read - Read Book for free  BOOKS_AND_REFERENCE     4.5
# 141    Download free book with green book  BOOKS_AND_REFERENCE     4.6
# 142                             Wikipedia  BOOKS_AND_REFERENCE     4.4
# 143                         Amazon Kindle  BOOKS_AND_REFERENCE     4.2
# ...                                   ...                  ...     ...
# 10815           Golden Dictionary (FR-AR)  BOOKS_AND_REFERENCE     4.2
# 10819                           Fanfic-FR  BOOKS_AND_REFERENCE     3.3
# 10829      Bulgarian French Dictionary Fr  BOOKS_AND_REFERENCE     4.6
# 10833                         Chemin (fr)  BOOKS_AND_REFERENCE     4.8
# 10839       The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE     4.5
#
#        Reviews                Size      Installs  Type Price Content Rating  \
# ...

# %% [markdown]
# ## free apps of category BOOKS_AND_REFERENCE with rating more than 4.5

# %%
df_pr[df_pr['Rating']>=4.5]
# Out:
#                                       App             Category  Rating  \
# 139                  Wattpad 📖 Free Books  BOOKS_AND_REFERENCE     4.6
# 140      E-Book Read - Read Book for free  BOOKS_AND_REFERENCE     4.5
# 141    Download free book with green book  BOOKS_AND_REFERENCE     4.6
# 144                           Cool Reader  BOOKS_AND_REFERENCE     4.5
# 145          Dictionary - Merriam-Webster  BOOKS_AND_REFERENCE     4.5
# ...                                   ...                  ...     ...
# 10590          Florida - Pocket Brainbook  BOOKS_AND_REFERENCE     4.6
# 10724         English To Shona Dictionary  BOOKS_AND_REFERENCE     4.6
# 10829      Bulgarian French Dictionary Fr  BOOKS_AND_REFERENCE     4.6
# 10833                         Chemin (fr)  BOOKS_AND_REFERENCE     4.8
# 10839       The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE     4.5
#
#        Reviews                Size      Installs  Type Price Content Rating  \
# ...

# %%
df_rating = df_pr[df_pr['Rating']>=4.5]
df_rating[df_rating['Type']=='Free']
# Out:
#                                       App             Category  Rating  \
# 139                  Wattpad 📖 Free Books  BOOKS_AND_REFERENCE     4.6
# 140      E-Book Read - Read Book for free  BOOKS_AND_REFERENCE     4.5
# 141    Download free book with green book  BOOKS_AND_REFERENCE     4.6
# 144                           Cool Reader  BOOKS_AND_REFERENCE     4.5
# 145          Dictionary - Merriam-Webster  BOOKS_AND_REFERENCE     4.5
# ...                                   ...                  ...     ...
# 10590          Florida - Pocket Brainbook  BOOKS_AND_REFERENCE     4.6
# 10724         English To Shona Dictionary  BOOKS_AND_REFERENCE     4.6
# 10829      Bulgarian French Dictionary Fr  BOOKS_AND_REFERENCE     4.6
# 10833                         Chemin (fr)  BOOKS_AND_REFERENCE     4.8
# 10839       The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE     4.5
#
#        Reviews                Size      Installs  Type Price Content Rating  \
# ...

# %%
df_pr=df[df['Category']=='ART_AND_DESIGN']
df_pr = df_pr[df_pr['Rating']>=4.5]

result = df_pr[df_pr['Type']=='Free'].values

# %%
for i in result:
    print(i[0])
# Out:
# U Launcher Lite – FREE Live Cool Themes, Hide Apps
# Sketch - Draw & Paint
# Kids Paint Free - Drawing Fun
# Mandala Coloring Book
# Photo Designer - Write your name with shapes
# 350 Diy Room Decor Ideas
# ibis Paint X
# Superheroes Wallpapers | 4K Backgrounds
# HD Mickey Minnie Wallpapers
# Harley Quinn wallpapers HD
# Colorfit - Drawing & Coloring
# Anime Manga Coloring Book
# I Creative Idea
# UNICORN - Color By Number & Pixel Art Coloring
# PIP Camera - PIP Collage Maker
# Sad Poetry Photo Frames 2018
# Canva: Poster, banner, card maker & graphic design
# Install images with music to make video without Net - 2018
# Cardi B Wallpaper
# X Launcher: With OS11 Style Theme & Control Center
# AJ Styles HD Wallpapers
# Fantasy theme dark bw black building
# Spring flowers theme couleurs d t space
